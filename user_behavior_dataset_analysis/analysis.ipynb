# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')

# %%
df = pd.read_csv("user_behavior_dataset.csv")
df
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0          1      Google Pixel 5          Android                       393
# 1          2           OnePlus 9          Android                       268
# 2          3        Xiaomi Mi 11          Android                       154
# 3          4      Google Pixel 5          Android                       239
# 4          5           iPhone 12              iOS                       187
# ..       ...                 ...              ...                       ...
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
# ...

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
df.tail()
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 695                         3.9                     1082
# 696                         6.8                     1965
# 697                         3.1                      942
# 698                         1.7                      431
# 699                         5.4                     1306
#
#      Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 695                        26                  381   22    Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User ID                     700 non-null    int64
#  1   Device Model                700 non-null    object
#  2   Operating System            700 non-null    object
#  3   App Usage Time (min/day)    700 non-null    int64
#  4   Screen On Time (hours/day)  700 non-null    float64
#  5   Battery Drain (mAh/day)     700 non-null    int64
#  6   Number of Apps Installed    700 non-null    int64
#  7   Data Usage (MB/day)         700 non-null    int64
#  8   Age                         700 non-null    int64
#  9   Gender                      700 non-null    object
#  10  User Behavior Class         700 non-null    int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 60.3+ KB

# %%
df.describe()
# Out:
#          User ID  App Usage Time (min/day)  Screen On Time (hours/day)  \
# count  700.00000                700.000000                  700.000000
# mean   350.50000                271.128571                    5.272714
# std    202.21688                177.199484                    3.068584
# min      1.00000                 30.000000                    1.000000
# 25%    175.75000                113.250000                    2.500000
# 50%    350.50000                227.500000                    4.900000
# 75%    525.25000                434.250000                    7.400000
# max    700.00000                598.000000                   12.000000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               700.000000                700.000000           700.000000
# mean               1525.158571                 50.681429           929.742857
# std                 819.136414                 26.943324           640.451729
# ...

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
df["Device Model"].unique()
# Out:
# array(['Google Pixel 5', 'OnePlus 9', 'Xiaomi Mi 11', 'iPhone 12',
#        'Samsung Galaxy S21'], dtype=object)

# %%
df["Device Model"].value_counts()
# Out:
# Xiaomi Mi 11          146
# iPhone 12             146
# Google Pixel 5        142
# OnePlus 9             133
# Samsung Galaxy S21    133
# Name: Device Model, dtype: int64

# %%
demo_table = df["Device Model"].value_counts()

plt.figure(figsize=(10,5))
plt.bar(demo_table.index, demo_table.values, color=['yellow', 'green', 'cyan', 'red', 'white'])
plt.title("Device Model")
plt.xlabel("Phone Models")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
df["Operating System"].unique()
# Out:
# array(['Android', 'iOS'], dtype=object)

# %%
df["Operating System"].value_counts()
# Out:
# Android    554
# iOS        146
# Name: Operating System, dtype: int64

# %%
opsy_table = df["Operating System"].value_counts()

plt.figure(figsize=(10,5))
plt.bar(opsy_table.index, opsy_table.values, color = ['Red', 'blue'])
plt.title("Operating System")
plt.ylabel("Numbers of Users")
plt.xlabel("System")
# Out:
# Text(0.5, 0, 'System')

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
df["App Usage Time (min/day)"].head()
# Out:
# 0    393
# 1    268
# 2    154
# 3    239
# 4    187
# Name: App Usage Time (min/day), dtype: int64

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
group_11 = df[df['App Usage Time (min/day)'] > 500]['App Usage Time (min/day)'].reset_index(drop=True)
group_22 = df[(df['App Usage Time (min/day)'] > 250) & (df['App Usage Time (min/day)'] <= 500)]['App Usage Time (min/day)'].reset_index(drop=True)
group_33 = df[df['App Usage Time (min/day)'] <= 250] ['App Usage Time (min/day)'].reset_index(drop=True)

group_1 = len(group_11)
group_2 = len(group_22)
group_3 = len(group_33)


print(group_1)
print(group_2)
print(group_3)
# Out:
# 122
# 205
# 373

# %%
group_labels = ['+500', '250-500', '250 and less']
group_counts = [group_1, group_2, group_3]

plt.figure(figsize=(10, 6))
plt.bar(group_labels, group_counts, color=['blue', 'green', 'red'])
plt.title('App Usage Time')
plt.xlabel('min/day')
plt.ylabel('Counts')
plt.xticks(rotation=0)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, '+500'), Text(1, 0, '250-500'), Text(2, 0, '250 and less')])

# %%
df.tail()
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 695                         3.9                     1082
# 696                         6.8                     1965
# 697                         3.1                      942
# 698                         1.7                      431
# 699                         5.4                     1306
#
#      Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 695                        26                  381   22    Male
# ...

# %%
group_111 = df[df['Screen On Time (hours/day)'] > 4]['Screen On Time (hours/day)'].reset_index(drop=True)
group_222 = df[(df['Screen On Time (hours/day)'] > 2) & (df['Screen On Time (hours/day)'] <= 4)]['Screen On Time (hours/day)'].reset_index(drop=True)
group_333 = df[df['Screen On Time (hours/day)'] <= 2] ['Screen On Time (hours/day)'].reset_index(drop=True)

sot_1 = len(group_111)
sot_2 = len(group_222)
sot_3 = len(group_333)


print(sot_1)
print(sot_2)
print(sot_3)
# Out:
# 410
# 147
# 143

# %%
group_labels = ['+4', '4-2', '2 and less']
group_counts = [sot_1, sot_2, sot_3]

plt.figure(figsize=(10, 6))
plt.bar(group_labels, group_counts, color=['blue', 'green', 'red'])
plt.title('Screen On Time')
plt.xlabel('(hours/day)')
plt.ylabel('Counts')
plt.xticks(rotation=0)
# Out:
# ([0, 1, 2], [Text(0, 0, '+4'), Text(1, 0, '4-2'), Text(2, 0, '2 and less')])

# %%
df.head(10)
# Out:
#    User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0        1      Google Pixel 5          Android                       393
# 1        2           OnePlus 9          Android                       268
# 2        3        Xiaomi Mi 11          Android                       154
# 3        4      Google Pixel 5          Android                       239
# 4        5           iPhone 12              iOS                       187
# 5        6      Google Pixel 5          Android                        99
# 6        7  Samsung Galaxy S21          Android                       350
# 7        8           OnePlus 9          Android                       543
# 8        9  Samsung Galaxy S21          Android                       340
# 9       10           iPhone 12              iOS                       424
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# ...

# %%
df.tail(10)
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 690      691      Google Pixel 5          Android                       195
# 691      692           iPhone 12              iOS                       178
# 692      693        Xiaomi Mi 11          Android                       378
# 693      694        Xiaomi Mi 11          Android                       505
# 694      695  Samsung Galaxy S21          Android                       564
# 695      696           iPhone 12              iOS                        92
# 696      697        Xiaomi Mi 11          Android                       316
# 697      698      Google Pixel 5          Android                        99
# 698      699  Samsung Galaxy S21          Android                        62
# 699      700           OnePlus 9          Android                       212
#
#      Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 690                         5.7                     1447
# ...

# %%
group_1111 = df[df['Battery Drain (mAh/day)'] > 2200]['Battery Drain (mAh/day)'].reset_index(drop=True)
group_2222 = df[(df['Battery Drain (mAh/day)'] > 1000) & (df['Battery Drain (mAh/day)'] <= 2200)]['Battery Drain (mAh/day)'].reset_index(drop=True)
group_3333 = df[df['Battery Drain (mAh/day)'] <= 1000] ['Battery Drain (mAh/day)'].reset_index(drop=True)

bd_1 = len(group_1111)
bd_2 = len(group_2222)
bd_3 = len(group_3333)

group_labels = ['+2200', '2200-1000', '1000 and less']
group_counts = [bd_1, bd_2, bd_3]

plt.figure(figsize=(15,10))
plt.bar(group_labels, group_counts, color = ['red', 'green', 'blue'])
plt.title('Battery Drain')
plt.ylabel('Counts')
plt.xlabel('mAh/day')
plt.xticks(rotation=0)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, '+2200'), Text(1, 0, '2200-1000'), Text(2, 0, '1000 and less')])

# %%
bd_1 = len(group_1111)
bd_2 = len(group_2222)
bd_3 = len(group_3333)


print(bd_1)
print(bd_2)
print(bd_3)

print(group_1111)
print(group_2222)
print(group_3333)
# Out:
# 181
# 284
# 235
# 0      2956
# 1      2303
# 2      2571
# 3      2774
# 4      2803
#        ...
# 176    2776
# 177    2354
# 178    2424
# 179    2792
# 180    2422
# Name: Battery Drain (mAh/day), Length: 181, dtype: int64
# 0      1872
# 1      1331
# 2      1676
# 3      1367
# 4      1802
#        ...
# 279    1447
# 280    1898
# 281    1082
# 282    1965
# 283    1306
# Name: Battery Drain (mAh/day), Length: 284, dtype: int64
# 0      761
# 1      940
# 2      435
# 3      628
# 4      558
#       ...
# 230    334
# 231    325
# 232    856
# 233    942
# 234    431
# Name: Battery Drain (mAh/day), Length: 235, dtype: int64

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
group_11111 = df[df['Number of Apps Installed'] > 65]['Number of Apps Installed'].reset_index(drop=True)
group_22222 = df[(df['Number of Apps Installed'] > 40) & (df['Number of Apps Installed'] <= 65)]['Number of Apps Installed'].reset_index(drop=True)
group_33333 = df[df['Number of Apps Installed'] <= 40] ['Number of Apps Installed'].reset_index(drop=True)

nai_1 = len(group_11111)
nai_2 = len(group_22222)
nai_3 = len(group_33333)

group_labels = ['+65', '60-40', '40 and less']
group_counts = [nai_1, nai_2, nai_3]

plt.figure(figsize=(10,6))
plt.bar(group_labels, group_counts, color = ['red', 'green', 'blue'])
plt.title('Number of Apps Installed')
plt.ylabel('Counts')
plt.xlabel('Apps Installed')
plt.xticks(rotation=0)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, '+65'), Text(1, 0, '60-40'), Text(2, 0, '40 and less')])

# %%
nai_1 = len(group_11111)
nai_2 = len(group_22222)
nai_3 = len(group_33333)


print(nai_1)
print(nai_2)
print(nai_3)
# Out:
# 242
# 176
# 282

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
group_111111 = df[df['Data Usage (MB/day)'] > 1800]['Data Usage (MB/day)'].reset_index(drop=True)
group_222222 = df[(df['Data Usage (MB/day)'] > 800) & (df['Data Usage (MB/day)'] <= 1800)]['Data Usage (MB/day)'].reset_index(drop=True)
group_333333 = df[df['Data Usage (MB/day)'] <= 800] ['Data Usage (MB/day)'].reset_index(drop=True)

du_1 = len(group_111111)
du_2 = len(group_222222)
du_3 = len(group_333333)

group_labels = ['+1800', '1800-800', '800 and less']
group_counts = [du_1, du_2, du_3]

plt.figure(figsize=(10,6))
plt.bar(group_labels, group_counts, color = ['red', 'green', 'blue'])
plt.title('Data Usage (MB/day)')
plt.ylabel('Counts')
plt.xlabel('Data Usage')
plt.xticks(rotation=0)
# Out:
# ([0, 1, 2],
#  [Text(0, 0, '+1800'), Text(1, 0, '1800-800'), Text(2, 0, '800 and less')])

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
group_1111111 = df[df['Age'] > 45]['Age'].reset_index(drop=True)
group_2222222 = df[(df['Age'] > 25) & (df['Age'] <= 45)]['Age'].reset_index(drop=True)
group_3333333 = df[df['Age'] <= 25] ['Age'].reset_index(drop=True)

age_1 = len(group_1111111)
age_2 = len(group_2222222)
age_3 = len(group_3333333)

group_labels = ['+45', '45-25', '25-18']
group_counts = [age_1, age_2, age_3]

plt.figure(figsize=(10,6))
plt.bar(group_labels, group_counts, color = ['red', 'green', 'blue'])
plt.title('User Ages')
plt.ylabel('Counts')
plt.xlabel('Age')
plt.xticks(rotation=0)
# Out:
# ([0, 1, 2], [Text(0, 0, '+45'), Text(1, 0, '45-25'), Text(2, 0, '25-18')])

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Male      364
# Female    336
# Name: Gender, dtype: int64

# %%
gender_tablo = df['Gender'].value_counts()

# %%
plt.figure(figsize=(6,4))
plt.bar(gender_tablo.index, gender_tablo.values,width=0.4, color = ['red', 'blue'])
plt.title('User Genders')
plt.ylabel('Counts')
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...

# %%
ubc = df['User Behavior Class'].value_counts()

plt.figure(figsize=(6,4))
plt.bar(ubc.index, ubc.values,width=0.4, color = ['red', 'blue', 'yellow', 'green', 'purple'])
plt.title('User Behavior Class')
plt.ylabel('Counts')
plt.xlabel('Class')
# Out:
# Text(0.5, 0, 'Class')

# %%
df.head()
# Out:
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# 1                         4.7                     1331
# 2                         4.0                      761
# 3                         4.8                     1676
# 4                         4.3                     1367
#
#    Number of Apps Installed  Data Usage (MB/day)  Age  Gender  \
# 0                        67                 1122   40    Male
# 1                        42                  944   47  Female
# ...
